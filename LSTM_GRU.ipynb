# %% [markdown]
# # Tutorial For Recurrent Neural Network (RNN)

# %%
# !pip install kaggle
# !kaggle datasets download -d kalilurrahman/mastercard-stock-data-latest-and-updated
# !unzip mastercard-stock-data-latest-and-updated -d ./data

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
from tensorflow.random import set_seed

set_seed(455)
np.random.seed(455)
# Out:
# 2022-02-26 14:48:00.491931: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-26 14:48:00.491974: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## Data Analysis

# %%
# First, we get the data
dataset = pd.read_csv(
    "data/Mastercard_stock_history.csv", index_col="Date", parse_dates=["Date"]
).drop(["Dividends", "Stock Splits"], axis=1)
print(dataset.head())
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2006-05-25  3.748967  4.283869  3.739664  4.279217  395343000
# 2006-05-26  4.307126  4.348058  4.103398  4.179680  103044000
# 2006-05-30  4.183400  4.184330  3.986184  4.093164   49898000
# 2006-05-31  4.125723  4.219679  4.125723  4.180608   30002000
# 2006-06-01  4.179678  4.474572  4.176887  4.419686   62344000

# %%
print(dataset.describe())
# Out:
#               Open         High          Low        Close        Volume
# count  3872.000000  3872.000000  3872.000000  3872.000000  3.872000e+03
# mean    104.896814   105.956054   103.769349   104.882714  1.232250e+07
# std     106.245511   107.303589   105.050064   106.168693  1.759665e+07
# min       3.748967     4.102467     3.739664     4.083861  6.411000e+05
# 25%      22.347203    22.637997    22.034458    22.300391  3.529475e+06
# 50%      70.810079    71.375896    70.224002    70.856083  5.891750e+06
# 75%     147.688448   148.645373   146.822013   147.688438  1.319775e+07
# max     392.653890   400.521479   389.747812   394.685730  3.953430e+08

# %%
dataset.isna().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
tstart = 2016
tend = 2020

def train_test_plot(dataset, tstart, tend):
    dataset.loc[f"{tstart}":f"{tend}", "High"].plot(figsize=(16, 4), legend=True)
    dataset.loc[f"{tend+1}":, "High"].plot(figsize=(16, 4), legend=True)
    plt.legend([f"Train (Before {tend+1})", f"Test ({tend+1} and beyond)"])
    plt.title("MasterCard stock price")
    plt.show()

train_test_plot(dataset,tstart,tend)

# %% [markdown]
# ## Data Preprocessing

# %%
def train_test_split(dataset, tstart, tend):
    train = dataset.loc[f"{tstart}":f"{tend}", "High"].values
    test = dataset.loc[f"{tend+1}":, "High"].values
    return train, test

training_set, test_set = train_test_split(dataset, tstart, tend)

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0, 1))
training_set = training_set.reshape(-1, 1)
training_set_scaled = sc.fit_transform(training_set)

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(sequence) - 1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)


n_steps = 60
features = 1
# split into samples
X_train, y_train = split_sequence(training_set_scaled, n_steps)

# %%
# Reshaping X_train for efficient modelling
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],features)

# %% [markdown]
# ## LSTM Model

# %%
# The LSTM architecture
model_lstm = Sequential()
model_lstm.add(LSTM(units=125, activation="tanh", input_shape=(n_steps, features)))
model_lstm.add(Dense(units=1))

# Compiling the RNN
model_lstm.compile(optimizer="RMSprop", loss="mse")

model_lstm.summary()
# Out:
# 2022-02-26 14:48:02.002759: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-02-26 14:48:02.002998: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-02-26 14:48:02.003016: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-02-26 14:48:02.003044: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (114b8fea-7cc0-4508-90a1-3f2785a34401): /proc/driver/nvidia/version does not exist
# 2022-02-26 14:48:02.003269: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-02-26 14:48:02.037491: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 125)               63500
# _________________________________________________________________
# dense (Dense)                (None, 1)                 126
# =================================================================
# Total params: 63,626
# Trainable params: 63,626
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting to the training set
model_lstm.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 2022-02-26 14:48:02.285063: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-02-26 14:48:02.285534: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2499995000 Hz
# 38/38 [==============================] - 4s 74ms/step - loss: 0.0417
# Epoch 2/50
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0036
# Epoch 3/50
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0025
# Epoch 4/50
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0020
# Epoch 5/50
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0014
# Epoch 6/50
# 38/38 [==============================] - 3s 71ms/step - loss: 0.0012
# Epoch 7/50
# 38/38 [==============================] - 3s 71ms/step - loss: 9.2171e-04
# Epoch 8/50
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0014
# Epoch 9/50
# 38/38 [==============================] - 3s 72ms/step - loss: 0.0011
# Epoch 10/50
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0015
# Epoch 11/50
# 38/38 [==============================] - 3s 72ms/step - loss: 8.9516e-04
# Epoch 12/50
# 38/38 [==============================] - 3s 70ms/step - loss: 8.8822e-04
# Epoch 13/50
# 38/38 [==============================] - 3s 72ms/step - loss: 8.8349e-04
# Epoch 14/50
# 38/38 [==============================] - 3s 70ms/step - loss: 6.2628e-04
# Epoch 15/50
# 38/38 [==============================] - 3s 71ms/step - loss: 6.9371e-04
# Epoch 16/50
# 38/38 [==============================] - 3s 71ms/step - loss: 7.2575e-04
# Epoch 17/50
# 38/38 [==============================] - 3s 71ms/step - loss: 7.5349e-04
# Epoch 18/50
# 38/38 [==============================] - 3s 71ms/step - loss: 6.5068e-04
# Epoch 19/50
# 38/38 [==============================] - 3s 71ms/step - loss: 6.6712e-04
# Epoch 20/50
# 38/38 [==============================] - 3s 71ms/step - loss: 6.5184e-04
# Epoch 21/50
# 38/38 [==============================] - 3s 70ms/step - loss: 8.4075e-04
# Epoch 22/50
# 38/38 [==============================] - 3s 70ms/step - loss: 5.7652e-04
# Epoch 23/50
# 38/38 [==============================] - 3s 70ms/step - loss: 4.7700e-04
# Epoch 24/50
# 38/38 [==============================] - 2s 65ms/step - loss: 6.0640e-04
# Epoch 25/50
# 38/38 [==============================] - 3s 68ms/step - loss: 6.5676e-04
# Epoch 26/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.7348e-04
# Epoch 27/50
# 38/38 [==============================] - 2s 65ms/step - loss: 6.0236e-04
# Epoch 28/50
# 38/38 [==============================] - 2s 65ms/step - loss: 6.1910e-04
# Epoch 29/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.8511e-04
# Epoch 30/50
# 38/38 [==============================] - 2s 64ms/step - loss: 6.0520e-04
# Epoch 31/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.6746e-04
# Epoch 32/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.8545e-04
# Epoch 33/50
# 38/38 [==============================] - 3s 66ms/step - loss: 5.3285e-04
# Epoch 34/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.2935e-04
# Epoch 35/50
# 38/38 [==============================] - 3s 66ms/step - loss: 4.0013e-04
# Epoch 36/50
# 38/38 [==============================] - 2s 65ms/step - loss: 5.0319e-04
# Epoch 37/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.2720e-04
# Epoch 38/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.9838e-04
# Epoch 39/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.4029e-04
# Epoch 40/50
# 38/38 [==============================] - 3s 67ms/step - loss: 3.6425e-04
# Epoch 41/50
# 38/38 [==============================] - 3s 67ms/step - loss: 4.4100e-04
# Epoch 42/50
# 38/38 [==============================] - 2s 65ms/step - loss: 3.8730e-04
# Epoch 43/50
# 38/38 [==============================] - 2s 66ms/step - loss: 4.2768e-04
# Epoch 44/50
# 38/38 [==============================] - 2s 66ms/step - loss: 2.4801e-04
# Epoch 45/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.6014e-04
# Epoch 46/50
# 38/38 [==============================] - 2s 65ms/step - loss: 3.4246e-04
# Epoch 47/50
# 38/38 [==============================] - 2s 67ms/step - loss: 4.8949e-04
# Epoch 48/50
# 38/38 [==============================] - 2s 67ms/step - loss: 2.8320e-04
# Epoch 49/50
# 38/38 [==============================] - 3s 66ms/step - loss: 4.3686e-04
# Epoch 50/50
# 38/38 [==============================] - 2s 65ms/step - loss: 3.1475e-04

# %% [markdown]
# ## Results

# %%
dataset_total = dataset.loc[:,"High"]
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)

# %%
# Preparing X_test and predicting the prices
X_test, y_test = split_sequence(inputs, n_steps)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], features)
predicted_stock_price = model_lstm.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
def plot_predictions(test, predicted):
    plt.plot(test, color="gray", label="Real")
    plt.plot(predicted, color="red", label="Predicted")
    plt.title("MasterCard Stock Price Prediction")
    plt.xlabel("Time")
    plt.ylabel("MasterCard Stock Price")
    plt.legend()
    plt.show()


def return_rmse(test, predicted):
    rmse = np.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {:.2f}.".format(rmse))

# %%
# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 6.70.

# %% [markdown]
# ## GRU Model

# %%
# The GRU architecture
model_gru = Sequential()
# First GRU layer with Dropout regularisation
model_gru.add(GRU(units=125, activation="tanh", input_shape=(n_steps, features)))
model_gru.add(Dense(units=1))
# Compiling the RNN
model_gru.compile(optimizer="RMSprop", loss="mse")

model_gru.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 125)               48000
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 126
# =================================================================
# Total params: 48,126
# Trainable params: 48,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting to the training set
model_gru.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 4s 69ms/step - loss: 0.0582
# Epoch 2/50
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0044
# Epoch 3/50
# 38/38 [==============================] - 3s 67ms/step - loss: 0.0020
# Epoch 4/50
# 38/38 [==============================] - 3s 65ms/step - loss: 0.0013
# Epoch 5/50
# 38/38 [==============================] - 3s 68ms/step - loss: 9.4554e-04
# Epoch 6/50
# 38/38 [==============================] - 3s 67ms/step - loss: 9.9860e-04
# Epoch 7/50
# 38/38 [==============================] - 3s 68ms/step - loss: 6.1373e-04
# Epoch 8/50
# 38/38 [==============================] - 3s 67ms/step - loss: 7.9382e-04
# Epoch 9/50
# 38/38 [==============================] - 3s 66ms/step - loss: 7.8859e-04
# Epoch 10/50
# 38/38 [==============================] - 3s 66ms/step - loss: 8.1784e-04
# Epoch 11/50
# 38/38 [==============================] - 2s 65ms/step - loss: 5.6758e-04
# Epoch 12/50
# 38/38 [==============================] - 2s 65ms/step - loss: 5.9090e-04
# Epoch 13/50
# 38/38 [==============================] - 2s 67ms/step - loss: 6.3029e-04
# Epoch 14/50
# 38/38 [==============================] - 2s 67ms/step - loss: 5.8464e-04
# Epoch 15/50
# 38/38 [==============================] - 2s 65ms/step - loss: 5.1233e-04
# Epoch 16/50
# 38/38 [==============================] - 2s 65ms/step - loss: 5.7559e-04
# Epoch 17/50
# 38/38 [==============================] - 2s 65ms/step - loss: 6.6695e-04
# Epoch 18/50
# 38/38 [==============================] - 2s 63ms/step - loss: 4.2827e-04
# Epoch 19/50
# 38/38 [==============================] - 2s 63ms/step - loss: 4.6419e-04
# Epoch 20/50
# 38/38 [==============================] - 2s 65ms/step - loss: 5.1630e-04
# Epoch 21/50
# 38/38 [==============================] - 2s 63ms/step - loss: 5.7459e-04
# Epoch 22/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.3644e-04
# Epoch 23/50
# 38/38 [==============================] - 2s 65ms/step - loss: 3.8774e-04
# Epoch 24/50
# 38/38 [==============================] - 2s 64ms/step - loss: 5.0837e-04
# Epoch 25/50
# 38/38 [==============================] - 2s 63ms/step - loss: 4.5595e-04
# Epoch 26/50
# 38/38 [==============================] - 2s 65ms/step - loss: 3.5124e-04
# Epoch 27/50
# 38/38 [==============================] - 2s 64ms/step - loss: 3.8810e-04
# Epoch 28/50
# 38/38 [==============================] - 2s 64ms/step - loss: 4.8652e-04
# Epoch 29/50
# 38/38 [==============================] - 2s 65ms/step - loss: 3.8321e-04
# Epoch 30/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.4386e-04
# Epoch 31/50
# 38/38 [==============================] - 2s 65ms/step - loss: 2.8583e-04
# Epoch 32/50
# 38/38 [==============================] - 2s 63ms/step - loss: 3.2623e-04
# Epoch 33/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.3743e-04
# Epoch 34/50
# 38/38 [==============================] - 2s 64ms/step - loss: 3.6761e-04
# Epoch 35/50
# 38/38 [==============================] - 2s 63ms/step - loss: 3.2427e-04
# Epoch 36/50
# 38/38 [==============================] - 2s 63ms/step - loss: 4.1345e-04
# Epoch 37/50
# 38/38 [==============================] - 2s 63ms/step - loss: 3.7036e-04
# Epoch 38/50
# 38/38 [==============================] - 2s 63ms/step - loss: 4.1585e-04
# Epoch 39/50
# 38/38 [==============================] - 2s 65ms/step - loss: 4.5516e-04
# Epoch 40/50
# 38/38 [==============================] - 2s 60ms/step - loss: 3.4485e-04
# Epoch 41/50
# 38/38 [==============================] - 2s 62ms/step - loss: 3.1372e-04
# Epoch 42/50
# 38/38 [==============================] - 2s 62ms/step - loss: 3.2389e-04
# Epoch 43/50
# 38/38 [==============================] - 2s 62ms/step - loss: 4.4353e-04
# Epoch 44/50
# 38/38 [==============================] - 2s 60ms/step - loss: 2.3637e-04
# Epoch 45/50
# 38/38 [==============================] - 2s 61ms/step - loss: 3.6086e-04
# Epoch 46/50
# 38/38 [==============================] - 2s 60ms/step - loss: 3.4857e-04
# Epoch 47/50
# 38/38 [==============================] - 2s 60ms/step - loss: 4.2535e-04
# Epoch 48/50
# 38/38 [==============================] - 2s 63ms/step - loss: 2.7045e-04
# Epoch 49/50
# 38/38 [==============================] - 2s 60ms/step - loss: 4.2007e-04
# Epoch 50/50
# 38/38 [==============================] - 2s 62ms/step - loss: 2.7047e-04

# %% [markdown]
# ## Results

# %%
GRU_predicted_stock_price = model_gru.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)

# %%
# Visualizing the results for GRU
plot_predictions(test_set, GRU_predicted_stock_price)

# %%
# Evaluating GRU
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 5.50.
